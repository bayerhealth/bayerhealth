# %%
import pandas as pd
import numpy as np

# %%
facebook = pd.read_csv('facebook.csv')
facebook.drop('id', axis=1)
instagram = pd.read_csv('instagram.csv')
instagram.drop('id', axis=1)
reddit = pd.read_csv('reddit.csv')
reddit.drop('id', axis=1)
media = pd.read_csv('media.csv')
media.drop('id', axis=1)
# Out:
#                  datetime source                    category  \
# 0     2020-06-24 13:56:56  media                         NaN
# 1     2020-06-18 19:21:42  media                         NaN
# 2     2020-06-24 13:56:56  media                         NaN
# 3     2020-06-10 09:00:15  media                         NaN
# 4     2020-06-18 19:21:42  media                         NaN
# ...                   ...    ...                         ...
# 3342  2019-06-03 04:01:00  media             business.market
# 3343  2019-06-26 02:00:27  media            lifestyle.beauty
# 3344  2019-06-17 15:38:34  media                         NaN
# 3345  2019-06-04 00:00:00  media  technology.startup-digital
# 3346  2019-06-06 21:25:39  media                         NaN
#
#                                                   title  \
# 0     Simple ways to boost your immunity amid the CO...
# 1     OVER THE COUNTER: How to reduce stress during ...
# 2     Simple ways to boost your immunity amid the CO...
# ...

# %%
facebook.head()
# Out:
#    id             datetime    source  \
# 0   0  2020-06-21 08:42:01  facebook
# 1   1  2020-06-22 00:00:07  facebook
# 2   2  2020-06-22 10:54:15  facebook
# 3   3  2020-06-15 05:48:42  facebook
# 4   4  2020-06-26 18:44:09  facebook
#
#                                                 text  \
# 0  We recommend ginger supplements to boost the i...
# 1  Researchers at the Yerkes National Primate Res...
# 2  Further to our recent posts on vitamin D, we s...
# 3  Sunraysia Supplements are your one stop shop f...
# 4  Is your body in the "remodeling" stage? :)  He...
#
#                                  hashtag
# 0                                     []
# 1                                     []
# 2  ['shoplocal', 'supportlocalbusiness']
# 3                                     []
# 4                                     []

# %%
instagram.head()
# Out:
#   id             datetime     source  \
# 0  0  2020-06-11 14:55:23  instagram
# 1  1  2020-06-29 12:58:56  instagram
# 2  2  2020-06-30 19:57:42  instagram
# 3  3  2020-06-23 08:51:35  instagram
# 4  4  2020-06-20 12:36:16  instagram
#
#                                                 text gender  impression
# 0  It’s possible to nurture your immune system na...    NaN       717.0
# 1  3 powerful ingredients in one supplement: Say ...    NaN       250.0
# 2  Why supplement with Vitamins B & C?⁣\nYour adr...      M    256172.0
# 3  GIDDY-UP! 20% off our supplements for the immu...    NaN     11241.0
# 4  Smoothie and Sunshine ☀️ ⁣\n⁣\n⁣\n⁣\n⁣\n⁣\n#be...      F      1778.0

# %%
reddit.head()
# Out:
#    id             datetime                                              title  \
# 0   0  2020-06-07 06:14:00  self diagnosing myself with genital warts and ...
# 1   1  2020-06-30 21:01:00           Joe Rogan Experience #1499 - Aron Snyder
# 2   2  2020-06-02 05:02:00                                           Immunity
# 3   3  2020-06-24 16:48:00  Jim Mattis urges Americans to wear masks and s...
# 4   4  2020-06-02 11:11:00  Supplements that changed your life? (Hopefully...
#
#                                                 text
# 0  \nI had a similar scare a few years back, but ...
# 1  \nThey want to believe they are personally hea...
# 2  \nWhat is the best supplements for immune syst...
# 3  \nEvidence has shown that supplements etc aren...
# 4  \nI regularly take a multivitamin as well as f...
